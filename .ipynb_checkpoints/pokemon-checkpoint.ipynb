# %%
import pandas as pd

# %%
#URLs to CSV from google drive
url1 = 'https://drive.google.com/file/d/1QO5zmytPKui7W9LpPmrI6DHZr1Ah7HFR/view?usp=sharing'
url2 = 'https://drive.google.com/file/d/1hPT-N6ECvbhZDSO4yucPKhVEhDQG0VQw/view?usp=sharing'
url3 = 'https://drive.google.com/file/d/1cCUBzDxIufQoDQTHnSV15eylitN4v_3W/view?usp=sharing'

# %%
#function to import csvs from google drive
def importer(url): 
    df = pd.read_csv('https://drive.google.com/uc?export=download&id='+url.split('/')[-2])
    return df

# %%
#function to check df
def checker(df):
    display(type(df))
    display(df.shape)
    display(df.head(3))

# %%
great = importer(url1)

# %%
ultra = importer(url2)

# %%
pkmn = importer(url3)

# %% [markdown]
# ---
# Cleaning
#
# ---

# %%
great = great.assign(league='great')
ultra = ultra.assign(league='ultra')
pkmn = pkmn.assign(league='dex_list')

# %%
checker(pkmn)
# Out:
# pandas.core.frame.DataFrame
# (1194, 14)
#    ID       Name Form  Type1   Type2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1  Bulbasaur       Grass  Poison    318  45      49       49       65
# 1   2    Ivysaur       Grass  Poison    405  60      62       63       80
# 2   3   Venusaur       Grass  Poison    525  80      82       83      100
#
#    Sp. Def  Speed  Generation    league
# 0       65     45           1  dex_list
# 1       80     60           1  dex_list
# 2      100     80           1  dex_list

# %%
#concat of great and ultra league
list = [great, ultra]
league = pd.concat(list)
league
# Out:
#              Pokemon  Score  Dex    Type 1   Type 2  Attack  Defense  Stamina  \
# 0           Medicham   96.3  308  fighting  psychic   106.9    139.5      141
# 1            Carbink   96.1  703      rock    fairy    84.9    247.9      126
# 2          Lickitung   94.9  108    normal     none    98.3    126.9      183
# 3    Gligar (Shadow)   94.1  207    ground   flying   108.0    146.2      130
# 4          Registeel   93.7  379     steel     none    95.5    189.6      130
# ..               ...    ...  ...       ...      ...     ...      ...      ...
# 648        Regigigas   39.2  486    normal     none   178.7    137.7      141
# 649   Shaymin (Land)   38.0  492     grass     none   152.6    157.6      169
# 650          Chansey   35.8  113    normal     none    63.0    120.2      421
# 651           Audino   33.6  531    normal     none   108.4    149.6      205
# 652          Slaking   28.2  289    normal     none   180.0    108.4      178
#
# ...

# %%
#need to find a way to export/save this df externally.
league.to_csv('data-analysis/league.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 league.to_csv('data-analysis/league.csv')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
# ...

# %%
league.Pokemon.value_counts().head(3)
# Out:
# Pokemon
# Lumineon    2
# Magmar      2
# Beartic     2
# Name: count, dtype: int64
